# %%
people = {
    'first': ['Mit', 'Rowland', 'Vish'],
    'last': ['Patel', 'Doe', 'Doe'],
    'email': ['mitpatel@gmail.com', 'rowlanddoe@email.com', 'vishdoe@email.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#      first   last                 email
# 0      Mit  Patel    mitpatel@gmail.com
# 1  Rowland    Doe  rowlanddoe@email.com
# 2     Vish    Doe     vishdoe@email.com

# %%
df['first'] + ' ' + df['last']
# Out:
# 0      Mit Patel
# 1    Rowland Doe
# 2       Vish Doe
# dtype: object

# %%
df['full_name'] = df['first'] + ' ' + df['last']

# %%
df
# Out:
#      first   last                 email    full_name
# 0      Mit  Patel    mitpatel@gmail.com    Mit Patel
# 1  Rowland    Doe  rowlanddoe@email.com  Rowland Doe
# 2     Vish    Doe     vishdoe@email.com     Vish Doe

# %%
df.drop(columns=['first', 'last'], inplace=True)

# %%
df
# Out:
#                   email    full_name
# 0    mitpatel@gmail.com    Mit Patel
# 1  rowlanddoe@email.com  Rowland Doe
# 2     vishdoe@email.com     Vish Doe

# %%
df['full_name'].str.split(' ', expand=True)
# Out:
#          0      1
# 0      Mit  Patel
# 1  Rowland    Doe
# 2     Vish    Doe

# %%
df[['first', 'last']] = df['full_name'].str.split(' ', expand=True)

# %%
df
# Out:
#                   email    full_name    first   last
# 0    mitpatel@gmail.com    Mit Patel      Mit  Patel
# 1  rowlanddoe@email.com  Rowland Doe  Rowland    Doe
# 2     vishdoe@email.com     Vish Doe     Vish    Doe

# %%
df.append({'first': 'Tony'}, ignore_index=True)
# Out:
# <ipython-input-33-eaefc03bde25>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({'first': 'Tony'}, ignore_index=True)
#                   email    full_name    first   last
# 0    mitpatel@gmail.com    Mit Patel      Mit  Patel
# 1  rowlanddoe@email.com  Rowland Doe  Rowland    Doe
# 2     vishdoe@email.com     Vish Doe     Vish    Doe
# 3                   NaN          NaN     Tony    NaN

# %%
people = {
    'first': ['Tony', 'Steve'],
    'last': ['Stark', 'Rogers'],
    'email': ['IronMan@avenge.com', 'Cap@avenge.com']
}
df2 = pd.DataFrame(people)

# %%
df2
# Out:
#    first    last               email
# 0   Tony   Stark  IronMan@avenge.com
# 1  Steve  Rogers      Cap@avenge.com

# %%
df.append(df2, ignore_index=True, sort=False)
# Out:
# <ipython-input-36-94ecd816c599>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df2, ignore_index=True, sort=False)
#                   email    full_name    first    last
# 0    mitpatel@gmail.com    Mit Patel      Mit   Patel
# 1  rowlanddoe@email.com  Rowland Doe  Rowland     Doe
# 2     vishdoe@email.com     Vish Doe     Vish     Doe
# 3    IronMan@avenge.com          NaN     Tony   Stark
# 4        Cap@avenge.com          NaN    Steve  Rogers

# %%
df = df.append(df2, ignore_index=True, sort=False)
# Out:
# <ipython-input-37-8793cd2f3458>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2, ignore_index=True, sort=False)

# %%
df
# Out:
#                   email    full_name    first    last
# 0    mitpatel@gmail.com    Mit Patel      Mit   Patel
# 1  rowlanddoe@email.com  Rowland Doe  Rowland     Doe
# 2     vishdoe@email.com     Vish Doe     Vish     Doe
# 3    IronMan@avenge.com          NaN     Tony   Stark
# 4        Cap@avenge.com          NaN    Steve  Rogers

# %%
df.drop(index=4)
# Out:
#                   email    full_name    first   last
# 0    mitpatel@gmail.com    Mit Patel      Mit  Patel
# 1  rowlanddoe@email.com  Rowland Doe  Rowland    Doe
# 2     vishdoe@email.com     Vish Doe     Vish    Doe
# 3    IronMan@avenge.com          NaN     Tony  Stark

# %%
df
# Out:
#                   email    full_name    first    last
# 0    mitpatel@gmail.com    Mit Patel      Mit   Patel
# 1  rowlanddoe@email.com  Rowland Doe  Rowland     Doe
# 2     vishdoe@email.com     Vish Doe     Vish     Doe
# 3    IronMan@avenge.com          NaN     Tony   Stark
# 4        Cap@avenge.com          NaN    Steve  Rogers

# %%
filt = df['last'] == 'Doe'
df.drop(index=df[filt].index)
# Out:
#                 email  full_name  first    last
# 0  mitpatel@gmail.com  Mit Patel    Mit   Patel
# 3  IronMan@avenge.com        NaN   Tony   Stark
# 4      Cap@avenge.com        NaN  Steve  Rogers
